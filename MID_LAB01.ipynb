# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrito2006/MI-LAB01-TA/blob/develop/MID_LAB01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 01 - Mineria de Datos
# ## Alumno: Torres Alvaradao Fabricio Ismael
# ## Ciclo y carrera: 5C28A

# %% [markdown]
# ## Importar librerias a usar

# %%
import pandas as pd

# %% [markdown]
# ## Primera base de datos
#
# ### Link de la base de datos del UCI Machine Learning Repository:
# ### https://archive.ics.uci.edu/dataset/320/student+performance

# %% [markdown]
# ### a. Lea cada base de datos y almacénela en un data frame indicando la cantidad de registros y atributos

# %%
df1 = pd.read_csv('/content/student-por.csv', sep = ";")

df1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# Cantidad de columnas y registros de la base de datos
df1.shape
# Out:
# (649, 33)

# %% [markdown]
# ### b. Determine la cantidad de variables numéricas y no numéricas. Además, indique si existen valores perdidos.

# %%
# Tipo de cada columna
df1.info() # Se observa la cantidad de variables numericas y no numericas en el apartado de "dtypes:"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
# Cantidad de variables númericas
df1.select_dtypes(include=['int64', 'float64']).shape[1]
# Out:
# 16

# %%
# Cantidad de variables no númericas
df1.select_dtypes(include=['object']).shape[1]
# Out:
# 17

# %%
# Cantidad de valores perdidos/nulos
df1.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ### c. Calcule estadísticos descriptivos para las variables numéricas (medidas de tendencia central, medidas de dispersión, valor máximo, valor mínimo, entre otras).

# %%
# Estadísticos descriptivo para las variables númericas
df1.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# ## Segunda base de datos
#
# ### Link de la base de datos de Kaggle:
# ### https://www.kaggle.com/datasets/zahidmughal2343/employee-data?resource=download

# %% [markdown]
# ### a. Lea cada base de datos y almacénela en un data frame indicando la cantidad de registros y atributos

# %%
# Link de la base de datos de Kaggle: https://www.kaggle.com/datasets/zahidmughal2343/employee-data?resource=download
df2 = pd.read_csv('/content/Employee 1000x.csv')

df2.head()
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female           tsharp@example.net
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538      17-11-89  Planning and development surveyor

# %%
# Cantidad de columnas y registros
df2.shape
# Out:
# (10000, 8)

# %% [markdown]
# ### b. Determine la cantidad de variables numéricas y no numéricas. Además, indique si existen valores perdidos.

# %%
# Tipo de cada columnas
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          10000 non-null  int64
#  1   First Name     10000 non-null  object
#  2   Last Name      10000 non-null  object
#  3   Sex            10000 non-null  object
#  4   Email          10000 non-null  object
#  5   Phone          10000 non-null  object
#  6   Date of birth  10000 non-null  object
#  7   Job Title      10000 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB

# %%
# Cantidad de variables númericas
df2.select_dtypes(include=['int64']).shape[1]
# Out:
# 1

# %%
# Cantidad de variables no númericas
df2.select_dtypes(include=['object']).shape[1]
# Out:
# 7

# %%
# Cantidad de valores perdidos / nulos
df2.isnull().sum()
# Out:
# Index            0
# First Name       0
# Last Name        0
# Sex              0
# Email            0
# Phone            0
# Date of birth    0
# Job Title        0
# dtype: int64

# %% [markdown]
# ### c. Calcule estadísticos descriptivos para las variables numéricas (medidas de tendencia central, medidas de dispersión, valor máximo, valor mínimo, entre otras).

# %%
# Estadísticos descriptivo para las variables númericas
df2.describe()
# Out:
#              Index
# count  10000.00000
# mean    5000.50000
# std     2886.89568
# min        1.00000
# 25%     2500.75000
# 50%     5000.50000
# 75%     7500.25000
# max    10000.00000
